# %%
import os
import pandas as pd

base_path = os.path.abspath('.')
data_path = os.path.join(base_path, 'data/data.csv')
df = pd.read_csv(data_path)

# %%
df.head()
# Out:
#         name gender  count  year
# 0       Mary      F   7065  1880
# 1       Anna      F   2604  1880
# 2       Emma      F   2003  1880
# 3  Elizabeth      F   1939  1880
# 4     Minnie      F   1746  1880

# %%
df.shape
# Out:
# (1957046, 4)

# %%
df_2017 = df[df.year == 2017]

# %%
df_pivot = df.pivot_table(['count'], ['name', 'gender'], aggfunc='sum', fill_value=0)

# %%
df_pivot
# Out:
#                     count
# name        gender
# Aaban       M         114
# Aabha       F          35
# Aabid       M          16
# Aabidah     F           5
# Aabir       M          10
# Aabriella   F          38
# Aada        F          13
# Aadam       M         273
# Aadan       M         130
# Aadarsh     M         209
# Aadaya      F           8
# Aaden       F           5
#             M        4828
# Aadesh      M          22
# Aadhav      M         217
# Aadhavan    M          44
# Aadhi       M          54
# Aadhira     F         107
# Aadhiran    M           6
# Aadhvik     M          54
# Aadhvika    F          17
# Aadhya      F        1725
# Aadhyan     M          18
# Aadhyareddy F           6
# Aadhyasri   F           6
# Aadi        F          16
#             M         851
# Aadian      M           5
# Aadil       M         361
# Aadilynn    F           5
# ...                   ...
# Zyriah      F         419
# Zyrian      M          10
# ...

# %%
df_pivot.sort_values(['count'], axis=0, ascending=True, inplace=True)

# %%
df_pivot
# Out:
#                       count
# name        gender
# Gaoussou    M             5
# Hameedah    F             5
# Benedicte   F             5
# Hamaad      M             5
# Halyna      F             5
# Halye       F             5
# Sensi       F             5
# Benessa     F             5
# Halstead    M             5
# Senteria    F             5
# Sentrell    M             5
# Seojun      M             5
# Hally       M             5
# Seoyeon     F             5
# Seoyoon     F             5
# Hallema     F             5
# Halleli     F             5
# Halleh      F             5
# Bengiman    M             5
# Halit       M             5
# Sepia       F             5
# Sepp        M             5
# Sequeena    F             5
# Haleyjo     F             5
# Sequina     F             5
# Sequoya     M             5
# Sequoyia    F             5
# Haleia      F             5
# Serach      F             5
# Serae       F             5
# ...                     ...
# ...
